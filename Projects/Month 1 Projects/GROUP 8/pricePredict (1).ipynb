# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/californiahouseprice.csv")
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
df.shape
# Out:
# (20640, 10)

# %%
df["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df1 = df.drop(["longitude","latitude","population"], axis = 1)
df1.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  households  median_income  \
# 0                  41          880           129.0         126         8.3252
# 1                  21         7099          1106.0        1138         8.3014
# 2                  52         1467           190.0         177         7.2574
# 3                  52         1274           235.0         219         5.6431
# 4                  52         1627           280.0         259         3.8462
#
#   ocean_proximity  median_house_value
# 0        NEAR BAY              452600
# 1        NEAR BAY              358500
# 2        NEAR BAY              352100
# 3        NEAR BAY              341300
# 4        NEAR BAY              342200

# %%
df1.shape
# Out:
# (20640, 7)

# %%
df1.isnull().sum()
# Out:
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
df2 = df1.dropna()
df2.isnull().sum()
# Out:
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
df2.shape
# Out:
# (20433, 7)

# %%
df2.groupby("ocean_proximity")["ocean_proximity"].agg("count")
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# ISLAND           5
# NEAR BAY      2270
# NEAR OCEAN    2628
# Name: ocean_proximity, dtype: int64

# %%
df2.loc[df2["ocean_proximity"]=="ISLAND"]
# Out:
#       housing_median_age  total_rooms  total_bedrooms  households  \
# 8314                  27         1675           521.0         331
# 8315                  52         2359           591.0         431
# 8316                  52         2127           512.0         288
# 8317                  52          996           264.0         160
# 8318                  29          716           214.0         173
#
#       median_income ocean_proximity  median_house_value
# 8314         2.1579          ISLAND              450000
# 8315         2.8333          ISLAND              414700
# 8316         3.3906          ISLAND              300000
# 8317         2.7361          ISLAND              450000
# 8318         2.6042          ISLAND              287500

# %%
df3 = df2[~(df2["ocean_proximity"]=="ISLAND")]
df3.shape
# Out:
# (20428, 7)

# %%
df3["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN'], dtype=object)

# %%
dummies =  pd.get_dummies(df3["ocean_proximity"]).astype("int")
dummies
# Out:
#        <1H OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# 0              0       0         1           0
# 1              0       0         1           0
# 2              0       0         1           0
# 3              0       0         1           0
# 4              0       0         1           0
# ...          ...     ...       ...         ...
# 20635          0       1         0           0
# 20636          0       1         0           0
# 20637          0       1         0           0
# 20638          0       1         0           0
# 20639          0       1         0           0
#
# [20428 rows x 4 columns]

# %%
df4 = df3.drop(["ocean_proximity"],axis = 1)
df4.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  households  median_income  \
# 0                  41          880           129.0         126         8.3252
# 1                  21         7099          1106.0        1138         8.3014
# 2                  52         1467           190.0         177         7.2574
# 3                  52         1274           235.0         219         5.6431
# 4                  52         1627           280.0         259         3.8462
#
#    median_house_value
# 0              452600
# 1              358500
# 2              352100
# 3              341300
# 4              342200

# %%
df5 = pd.concat([df4,dummies],axis = 1)
df5.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  households  median_income  \
# 0                  41          880           129.0         126         8.3252
# 1                  21         7099          1106.0        1138         8.3014
# 2                  52         1467           190.0         177         7.2574
# 3                  52         1274           235.0         219         5.6431
# 4                  52         1627           280.0         259         3.8462
#
#    median_house_value  <1H OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# 0              452600          0       0         1           0
# 1              358500          0       0         1           0
# 2              352100          0       0         1           0
# 3              341300          0       0         1           0
# 4              342200          0       0         1           0

# %%
df5.rename(columns = {"<1H OCEAN":"<1HR FROM OCEAN"},inplace = True)

# %%
df5.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  households  median_income  \
# 0                  41          880           129.0         126         8.3252
# 1                  21         7099          1106.0        1138         8.3014
# 2                  52         1467           190.0         177         7.2574
# 3                  52         1274           235.0         219         5.6431
# 4                  52         1627           280.0         259         3.8462
#
#    median_house_value  <1HR FROM OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# 0              452600                0       0         1           0
# 1              358500                0       0         1           0
# 2              352100                0       0         1           0
# 3              341300                0       0         1           0
# 4              342200                0       0         1           0

# %%
df5.columns = df5.columns.str.replace('_', ' ')
df5.head()
# Out:
#    housing median age  total rooms  total bedrooms  households  median income  \
# 0                  41          880           129.0         126         8.3252
# 1                  21         7099          1106.0        1138         8.3014
# 2                  52         1467           190.0         177         7.2574
# 3                  52         1274           235.0         219         5.6431
# 4                  52         1627           280.0         259         3.8462
#
#    median house value  <1HR FROM OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# 0              452600                0       0         1           0
# 1              358500                0       0         1           0
# 2              352100                0       0         1           0
# 3              341300                0       0         1           0
# 4              342200                0       0         1           0

# %%
X = df5.drop("median house value",axis = 1)
Y = df5["median house value"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler1 = scaler.fit(X)

# %%
X_scaled = scaler.transform(X)
X_scaled
# Out:
# array([[0.78431373, 0.02233074, 0.01986344, ..., 0.        , 1.        ,
#         0.        ],
#        [0.39215686, 0.18050257, 0.17147734, ..., 0.        , 1.        ,
#         0.        ],
#        [1.        , 0.03726029, 0.02932961, ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.31372549, 0.05727657, 0.07510863, ..., 1.        , 0.        ,
#         0.        ],
#        [0.33333333, 0.04725571, 0.06331471, ..., 1.        , 0.        ,
#         0.        ],
#        [0.29411765, 0.07078183, 0.09543762, ..., 1.        , 0.        ,
#         0.        ]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred[:10]
# Out:
# array([ 50904.49632843, 258506.97803027, 171910.75550717,  69656.53210057,
#        254703.4226523 , 130117.54753256, 208206.15279063,  84521.64332511,
#        204919.47680994, 251871.89714896])

# %%
Y_test[:10]
# Out:
# 11998    164300
# 6807     258000
# 13029    147000
# 20099     79400
# 20480    196100
# 2776      57500
# 7435     179100
# 19770     77200
# 9509     154600
# 15934    271300
# Name: median house value, dtype: int64

# %%
model.score(X_train, Y_train)
# Out:
# 0.6137083081396402
